# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#use numpy to pull 1000 random numbers distributed uniformly between 0,1
x = np.random.normal(0,1,1000)

#histohram the random numbers into 100 bins, and plot the histogram
plt.hist(x,bins=100,alpha=0.5,edgecolor='black')
plt.xlabel("x")
plt.ylabel("n per bin")
plt.sa
# Out:
# Text(0, 0.5, 'n per bin')
